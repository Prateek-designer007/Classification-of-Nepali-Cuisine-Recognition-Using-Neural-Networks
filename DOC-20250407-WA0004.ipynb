# %%
import os
import cv2
import numpy as np
from tqdm import tqdm
from random import shuffle
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Image settings
IMG_SIZE = 150
DATASET_DIR = 'Traditional Food of Nepal'
LABELS = ['Bara', 'Ghongi', 'Gundruk', 'Momo', 'Selroti','Thekua','Yomari']
X = []
Z = []

# %%
# Load dataset
def assign_label(img, label):
    return label

def make_train_data(label, DIR):
    for img_name in tqdm(os.listdir(DIR)):
        label_val = assign_label(img_name, label)
        path = os.path.join(DIR, img_name)
        img = cv2.imread(path)
        try:
            img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
            X.append(np.array(img))
            Z.append(str(label_val))
        except Exception as e:
            pass

for label in LABELS:
    make_train_data(label, os.path.join(DATASET_DIR, label))

# Label encoding
le = LabelEncoder()
Y = le.fit_transform(Z)
Y = to_categorical(Y, len(LABELS))

X = np.array(X)
# Out:
# 100%|██████████| 252/252 [00:00<00:00, 1859.94it/s]
# 100%|██████████| 252/252 [00:00<00:00, 2073.54it/s]
# 100%|██████████| 273/273 [00:00<00:00, 1819.57it/s]
# 100%|██████████| 279/279 [00:00<00:00, 724.22it/s]
# 100%|██████████| 250/250 [00:00<00:00, 1432.52it/s]
# 100%|██████████| 259/259 [00:00<00:00, 1409.21it/s]
# 100%|██████████| 253/253 [00:00<00:00, 2045.31it/s]

# %%
# Train/test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# # ImageDataGenerator (normalization + augmentation)
# datagen = ImageDataGenerator(
#     # rescale=1./255,
#     rotation_range=25,
#     width_shift_range=0.35,
#     height_shift_range=0.35,
#     shear_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     fill_mode='nearest',
#     # featurewise_center=True,
#     # featurewise_std_normalization=True,

# )
# datagen.fit(x_train)

datagen = ImageDataGenerator(
    rotation_range=15,          # Reduced from 25
    width_shift_range=0.15,     # Reduced from 0.35
    height_shift_range=0.15,    # Reduced from 0.35
    shear_range=0.1,            # Reduced from 0.2
    zoom_range=0.1,             # Reduced from 0.2
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen.fit(x_train)

# %%
# Load EfficientNetB0 base model
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# %%
# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

# Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
# x = Dropout(0.2)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.25)(x)
predictions = Dense(len(LABELS), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5)
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(
    datagen.flow(x_train, y_train, batch_size=64),
    validation_data=(x_test, y_test),
    epochs=100,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 959ms/step - accuracy: 0.2050 - loss: 1.9811 - val_accuracy: 0.5522 - val_loss: 1.5151
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 815ms/step - accuracy: 0.5719 - loss: 1.4645 - val_accuracy: 0.7280 - val_loss: 1.1275
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 821ms/step - accuracy: 0.7143 - loss: 1.1276 - val_accuracy: 0.7995 - val_loss: 0.8538
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 811ms/step - accuracy: 0.7790 - loss: 0.8985 - val_accuracy: 0.8324 - val_loss: 0.6718
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 811ms/step - accuracy: 0.7990 - loss: 0.7468 - val_accuracy: 0.8489 - val_loss: 0.5470
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 811ms/step - accuracy: 0.8342 - loss: 0.6361 - val_accuracy: 0.8764 - val_loss: 0.4659
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 810ms/step - accuracy: 0.8441 - loss: 0.5691 - val_accuracy: 0.8956 - val_loss: 0.4085
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 811ms/step - accuracy: 0.8891 - loss: 0.4720 - val_accuracy: 0.9038 - val_loss: 0.3652
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 814ms/step - accuracy: 0.8756 - loss: 0.4383 - val_accuracy: 0.9121 - val_loss: 0.3331
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 809ms/step - accuracy: 0.8909 - loss: 0.3999 - val_accuracy: 0.9203 - val_loss: 0.3056
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 812ms/step - accuracy: 0.8994 - loss: 0.3519 - val_accuracy: 0.9231 - val_loss: 0.2823
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 817ms/step - accuracy: 0.8972 - loss: 0.3509 - val_accuracy: 0.9258 - val_loss: 0.2672
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 823ms/step - accuracy: 0.8963 - loss: 0.3527 - val_accuracy: 0.9368 - val_loss: 0.2527
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 883ms/step - accuracy: 0.9086 - loss: 0.3361 - val_accuracy: 0.9396 - val_loss: 0.2434
# Epoch 15/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 919ms/step - accuracy: 0.9027 - loss: 0.3132 - val_accuracy: 0.9451 - val_loss: 0.2350
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 871ms/step - accuracy: 0.9036 - loss: 0.2968 - val_accuracy: 0.9505 - val_loss: 0.2224
# Epoch 17/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 844ms/step - accuracy: 0.9245 - loss: 0.2885 - val_accuracy: 0.9505 - val_loss: 0.2125
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 959ms/step - accuracy: 0.9399 - loss: 0.2436 - val_accuracy: 0.9478 - val_loss: 0.2074
# Epoch 19/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 866ms/step - accuracy: 0.9426 - loss: 0.2310 - val_accuracy: 0.9505 - val_loss: 0.2017
# Epoch 20/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 848ms/step - accuracy: 0.9290 - loss: 0.2544 - val_accuracy: 0.9533 - val_loss: 0.1985
# Epoch 21/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 800ms/step - accuracy: 0.9307 - loss: 0.2298 - val_accuracy: 0.9505 - val_loss: 0.1949
# Epoch 22/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 860ms/step - accuracy: 0.9360 - loss: 0.2295 - val_accuracy: 0.9505 - val_loss: 0.1905
# Epoch 23/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 809ms/step - accuracy: 0.9288 - loss: 0.2258 - val_accuracy: 0.9560 - val_loss: 0.1830
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 815ms/step - accuracy: 0.9425 - loss: 0.2058 - val_accuracy: 0.9588 - val_loss: 0.1751
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 802ms/step - accuracy: 0.9561 - loss: 0.1886 - val_accuracy: 0.9505 - val_loss: 0.1827
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 807ms/step - accuracy: 0.9545 - loss: 0.1734 - val_accuracy: 0.9560 - val_loss: 0.1741
# Epoch 27/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 802ms/step - accuracy: 0.9558 - loss: 0.1776 - val_accuracy: 0.9533 - val_loss: 0.1690
# Epoch 28/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 829ms/step - accuracy: 0.9442 - loss: 0.1806 - val_accuracy: 0.9560 - val_loss: 0.1668
# Epoch 29/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 803ms/step - accuracy: 0.9606 - loss: 0.1578 - val_accuracy: 0.9560 - val_loss: 0.1720
# Epoch 30/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 806ms/step - accuracy: 0.9580 - loss: 0.1837 - val_accuracy: 0.9533 - val_loss: 0.1663
# Epoch 31/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 806ms/step - accuracy: 0.9534 - loss: 0.1723 - val_accuracy: 0.9560 - val_loss: 0.1645
# Epoch 32/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 18s 798ms/step - accuracy: 0.9534 - loss: 0.1748 - val_accuracy: 0.9588 - val_loss: 0.1613
# Epoch 33/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 803ms/step - accuracy: 0.9537 - loss: 0.1604 - val_accuracy: 0.9533 - val_loss: 0.1656
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 19s 837ms/step - accuracy: 0.9649 - loss: 0.1490 - val_accuracy: 0.9560 - val_loss: 0.1628

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()
plt.savefig('loss_curve.png')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()
plt.savefig('accuracy_curve.png')

# %%
# getting predictions on val set.
pred=model.predict(x_test)
pred_digits=np.argmax(pred,axis=1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step

# %%
# now storing some properly as well as misclassified indexes'.
i=0
prop_class=[]
mis_class=[]

for i in range(len(y_test)):
    if(np.argmax(y_test[i])==pred_digits[i]):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(y_test)):
    if(not np.argmax(y_test[i])==pred_digits[i]):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# %%
import matplotlib.pyplot as plt
import warnings

# Ignore warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Plot predictions
count = 0
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(15, 15)

for i in range(4):
    for j in range(2):
        ax[i, j].imshow(x_test[prop_class[count]])
        ax[i, j].set_title(
            "Predicted Food: " + str(le.inverse_transform([pred_digits[prop_class[count]]])[0]) + "\n" +
            "Actual Food: " + str(le.inverse_transform([np.argmax(y_test[prop_class[count]])])[0])
        )
        ax[i, j].axis('off')  # Hide axis ticks
        plt.tight_layout()
        count += 1

plt.show()
plt.savefig('correct_prds.png')

# %%
import matplotlib.pyplot as plt
import warnings

# Ignore warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Plot misclassified predictions
count = 0
fig, ax = plt.subplots(4, 2)
fig.set_size_inches(15, 15)

for i in range(4):
    for j in range(2):
        index = mis_class[count]
        ax[i, j].imshow(x_test[index])
        ax[i, j].set_title(
            "Predicted Food: " + str(le.inverse_transform([pred_digits[index]])[0]) + "\n" +
            "Actual Food: " + str(le.inverse_transform([np.argmax(y_test[index])])[0])
        )
        ax[i, j].axis('off')  # Hide axes
        plt.tight_layout()
        count += 1

plt.show()
plt.savefig('misclassified_preds.png')

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Predict on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert predictions to class labels

# Get true labels
y_true = np.argmax(y_test, axis=1)  # If y_test is one-hot encoded

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(0, cm.shape[1]), yticklabels=np.arange(0, cm.shape[0]))
plt.title("Confusion Matrix")
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step

# %%
from sklearn.metrics import classification_report

# Generate classification report
report = classification_report(y_true, y_pred_classes)

# Print the classification report
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        44
#            1       0.95      0.89      0.92        61
#            2       0.90      0.94      0.92        50
#            3       0.93      0.98      0.95        51
#            4       1.00      0.98      0.99        49
#            5       0.98      0.98      0.98        51
#            6       0.98      1.00      0.99        58
#
#     accuracy                           0.96       364
#    macro avg       0.96      0.96      0.96       364
# weighted avg       0.96      0.96      0.96       364
